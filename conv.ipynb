# %%
import tflite2onnx

# %%
tflite2onnx.convert(r'models\modelsinception_resnet_v2.tflite', r'models\model_emb.onnx')
# Out:
# Data type int8 not supported/tested yet, the generated model may contain error
# Data type int8 not supported/tested yet, the generated model may contain error
# Data type int8 not supported/tested yet, the generated model may contain error
# Data type int8 not supported/tested yet, the generated model may contain error
# Data type int8 not supported/tested yet, the generated model may contain error
# Data type int8 not supported/tested yet, the generated model may contain error
# Data type int8 not supported/tested yet, the generated model may contain error
# Data type int8 not supported/tested yet, the generated model may contain error
# Data type int8 not supported/tested yet, the generated model may contain error
# Data type int8 not supported/tested yet, the generated model may contain error
# Data type int8 not supported/tested yet, the generated model may contain error
# Data type int8 not supported/tested yet, the generated model may contain error
# ...
